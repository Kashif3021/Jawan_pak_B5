# %%
student_data = [
    ["Kashif", "25", "80", "70", "90"],
    ["Ali", "22", "75", "85", "80"],
    ["Ahmed", "24", "90", "80", "85"]
]

for per in student_data: # if we see that data check for student_data and storeinng in per
    chem = int(per[2])  # in line data store and conveting form stirng to int
    phy = int(per[3]) # in line data store and conveting form stirng to int
    math = int(per[4]) # in line data store and conveting form stirng to int

    percentage = round((chem + phy + math) / 300 * 100, 2)  # if we see that data already store in chem,math,phy

    per.append(percentage)  # my main question is that all data is store in percentage but how append data in student_data

print(student_data)
