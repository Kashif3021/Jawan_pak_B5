# %% [markdown]
# ### Strings in Python
# #### A string is a sequence of characters. In Python, strings are enclosed
# #### within single (') or double (") or triple (""") quotation marks

# %%
Name = "Muhammad Kashif"
Age = 29
city = "Hangu"

# %%
print(Name)
# Out:
# Muhammad Kashif

# %%
print(type(Name))
# Out:
# <class 'str'>

# %%
print(city)
# Out:
# Hangu

# %%
print(Name,Age,city)
# Out:
# Muhammad Kashif 29 Hangu

# %%
print(""" "My Name is Kashif" """)
# Out:
#  "My Name is Kashif"

# %%
print("\"My Name is Kashif\"")
# Out:
# "My Name is Kashif"
