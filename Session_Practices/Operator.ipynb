# %% [markdown]
# ## Comparison Operator

# %%
marks = 10
total_marks = 15
marks == total_marks
# Out:
# False

# %%
6 == 6 and 6 > 10
# Out:
# False

# %%
6 < 6 or 6 < 10
# Out:
# True

# %%
not (6 < 6 or 6 < 10 and 6 == 6 and 6 > 10)
# Out:
# True

# %%
 29 >= 18
# Out:
# True

# %%
a = "Python"
b = 'C++0'
len(a) == len(b)
# Out:
# False
