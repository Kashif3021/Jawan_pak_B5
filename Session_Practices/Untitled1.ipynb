# %%
Number = float(input('Ennter a Number'))
if Number%2==0 and Number >50:
    print ("Even and Big")
elif Number%2==0 and Number<50:
    print("Even and Big")
elif Number%2 and Number>50:
    print("Odd and small")
# Out:
# Ennter a Number 6
# Even and Big
