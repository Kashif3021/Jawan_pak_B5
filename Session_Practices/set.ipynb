# %% [markdown]
# ## SET {}
# A set in Python is an unordered collection of unique elements. This means that a set cannot contain duplicate values, and the elements are stored in no specific order.
#
# Unordered: The elements in a set do not maintain any specific order.
#
# Unique: Sets cannot contain duplicate elements. If you try to add a duplicate element, it will not be added.
#
# Mutable: You can add or remove elements from a set after it is created.
#
# No indexing: Sets do not support indexing or slicing like lists.

# %% [markdown]
# ## Create Set in Python
# There are two primary ways to create a set in Python:
# #### First Way
#       Each element separated by comma inside the curly braces
# My_set {element1,element2,element3}
# #### Second way
# #### Using set() Constructor
# ##### My_lists = [4,,5,6,9,10]
# ##### My_lists =set([4,,5,6,9,10])

# %%
dir(set())
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
My_marks = {20,40,50,60,70,90}
My_marks
# Out:
# {20, 40, 50, 60, 70, 90}

# %%
fruits_list = ["Fruits","Mango","Watermelon","Cherry"]
fruits_list
# Out:
# ['Fruits', 'Mango', 'Watermelon', 'Cherry']

# %%
# using set() Constructor
New_set = set(fruits_list)
New_set
# Out:
# {'Cherry', 'Fruits', 'Mango', 'Watermelon'}

# %% [markdown]
# # Method of Set
# Adding & Removing Elements

# %% [markdown]
# ## add()
# #### s.add(x)
# #### Adds a single element x to the set.

# %%
# adding an element in set
My_marks
# Out:
# {20, 40, 50, 60, 70, 90}

# %%
My_marks.add(100)
My_marks
# Out:
# {20, 40, 50, 60, 70, 90, 100}

# %% [markdown]
# ### update()
# #### s.update(iterable)
# #### Adds multiple items from any iterable (list, set, tuple).

# %%
My_marks
# Out:
# {20, 40, 50, 60, 70, 90, 100}

# %%
My_marks.update(20,2030)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 My_marks.update(20,2030)
#
# TypeError: 'int' object is not iterable

# %%
My_marks.update([80,2030])
My_marks
# Out:
# {20, 40, 50, 60, 70, 80, 90, 100, 2030}

# %%
My_marks.update((102,103))
My_marks
# Out:
# {20, 40, 50, 60, 70, 80, 90, 100, 102, 103, 2030}

# %%
My_marks.update({106,110})
My_marks
# Out:
# {20, 40, 50, 60, 70, 80, 90, 100, 102, 103, 106, 110, 2030}

# %% [markdown]
# ### remove()
# #### s.remove(x)
# #### Removes x. Raises KeyError if x is not found.

# %%
My_marks
# Out:
# {20, 40, 50, 60, 70, 80, 90, 100, 102, 103, 106, 110, 2030}

# %%
My_marks.remove(111)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 My_marks.remove(111)
#
# KeyError: 111

# %%
My_marks.remove(100)
My_marks
# Out:
# {20, 40, 50, 60, 70, 80, 90, 102, 103, 106, 110, 2030}

# %% [markdown]
# ### discard()
# #### s.discard(x)
# #### Removes x safely (no error if x is missing).

# %%
My_marks
# Out:
# {20, 40, 50, 60, 70, 80, 90, 102, 103, 106, 110, 2030}

# %%
My_marks.discard(88)
My_marks
# Out:
# {20, 40, 50, 60, 70, 80, 90, 102, 103, 106, 110, 2030}

# %%
My_marks.discard(20)
My_marks
# Out:
# {40, 50, 60, 70, 80, 90, 102, 103, 106, 110, 2030}

# %% [markdown]
# ### pop()
# #### s.pop()
# #### Removes and returns an arbitrary element.

# %%
My_marks
# Out:
# {40, 50, 60, 70, 80, 90, 102, 103, 106, 110, 2030}

# %%
My_marks.pop()
# Out:
# 70

# %% [markdown]
# ### clear()
# #### s.clear()
# #### Removes all elements, leaving an empty set.

# %%
marks = {10,60,70,90,80,90,100,200}
marks
# Out:
# {10, 60, 70, 80, 90, 100, 200}

# %%
marks.clear()
marks
# Out:
# set()

# %% [markdown]
# ## Mathematical Operations (Return a New Set)

# %% [markdown]
# #### union()
# ### |
# #### Returns all unique elements from both sets.

# %%
Set_A = {20,30,40,60,70}
Set_B = {80,90,100,110}

# %%
Set_union = Set_A.union(Set_B)
Set_union
# Out:
# {20, 30, 40, 60, 70, 80, 90, 100, 110}

# %%
Set_union1 = Set_B.union(Set_A)
Set_union1
# Out:
# {20, 30, 40, 60, 70, 80, 90, 100, 110}

# %% [markdown]
# ####  intersection()
# ####  &
# #### Returns only elements present in both sets.

# %%
Set_A
# Out:
# {20, 30, 40, 60, 70}

# %%
Set_B
# Out:
# {80, 90, 100, 110}

# %%
Set_A.intersection(Set_B)
# Out:
# set()

# %%
A = {20,30,40,60,90}
B = {40,30,60,70,80}

# %%
C = A.intersection(B)
C
# Out:
# {30, 40, 60}

# %% [markdown]
# ### difference()
# ### -
# #### Returns elements in the first set but not in the second.

# %%
A
# Out:
# {20, 30, 40, 60, 90}

# %%
B
# Out:
# {30, 40, 60, 70, 80}

# %%
A.difference(B)
# Out:
# {20, 90}

# %%
B.difference(A)
# Out:
# {70, 80}

# %% [markdown]
# ### symmetric_difference()
# #### ^
# #### Returns elements in either set, but not both.

# %%
A
# Out:
# {20, 30, 40, 60, 90}

# %%
B
# Out:
# {30, 40, 60, 70, 80}

# %%
A.symmetric_difference(B)
# Out:
# {20, 70, 80, 90}

# %% [markdown]
# ### In-Place Update Operations (Modify Existing Set)
# #### These modify the original set in place instead of returning a new one.

# %% [markdown]
# #### intersection_update()
# #### &=
# #### Keeps only elements found in both sets.

# %%
A
# Out:
# {20, 30, 40, 60, 90}

# %%
B
# Out:
# {30, 40, 60, 70, 80}

# %%
A.intersection_update(B)
# Out:
# None

# %%
print(A)
# Out:
# {40, 60, 30}

# %%
D = {40,30,50,60,90}

# %%
E = {30,40,60,70}

# %%
D.intersection_update(E)

# %%
print(D)
# Out:
# {40, 60, 30}

# %% [markdown]
# #### difference_update()
# ### -=
# #### Removes all elements of another set from this set.

# %%
D
# Out:
# {30, 40, 60}

# %%
E
# Out:
# {30, 40, 60, 70}

# %%
D.difference_update(E)

# %%
print(D)
# Out:
# set()
