# %%
number = [10,20,30]

# %%
number.inset[1]= 15
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 number.inset[1]= 15
#
# AttributeError: 'list' object has no attribute 'inset'
