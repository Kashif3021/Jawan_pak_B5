# %%
x = [1,2,3,4,6,6]
for y in x:
    print(y)
# Out:
# 1
# 2
# 3
# 4
# 6
# 6

# %%
x = 6
while x <= 10:
    print(x)
    x+= 1
# Out:
# 6
# 7
# 8
# 9
# 10

# %%
# Best example for while loops
X = 0
while not(1<=X<=100):
    X=int(input("Please Enter A Number"))
else:
    print("Valid No",X)
# Out:
# Please Enter A Number 101
# Please Enter A Number 0
# Please Enter A Number -0
# Please Enter A Number 22
# Valid No 22

# %%
# for loops
for i in range(2):
    x = int(input("Please enter a Number"))
    if 1<=x<=100:
        print("Valid Number",x)
        break
    else:
        print("invalid Number")
    
else:
    print("Run again program")
# Out:
# Please enter a Number 1000
# invalid Number
# Please enter a Number 563
# invalid Number
# Run again program

# %%
# for loops
for i in range(2):
    x = int(input("Please enter a Number"))
    if 1<=x<=100:
        print("Valid Number",x)
        break
    else:
        print("invalid Number")
# Out:
# Please enter a Number 1000
# invalid Number
# Please enter a Number 5000
# invalid Number
