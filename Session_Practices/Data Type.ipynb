# %% [raw]
# 𝗣𝗿𝗶𝗺𝗶𝘁𝗶𝘃𝗲 𝗗𝗮𝘁𝗮 𝗧𝘆𝗽𝗲𝘀
# Integer (int)
# An integer represents a whole number, which can be positive,negative or zero. It cannot contain any decimal Points

# %%
Marks = 200
# Display the data
print(Marks)
# Out:
# 200

# %%
Kashif_Employee_Id = 1150
# Display the Employee Id
print(Kashif_Employee_Id)
# Out:
# 1150

# %% [raw]
# Float (float)
# A float represents a real number that contains a decimal point
# Marks = 3.14, apple = 2.5, hight = 6.5
# Common Usage:
# High-precision measurement, Currency,Percentage or GPS Coordinates
# Notes:
# Even if a number is technically a whole number, adding .0 to it makes it a float in python
# Likes 5 in an int, but 5.0 is a float

# %%
Maths_marks = 25.5

# %%
print(Maths_marks)
# Out:
# 25.5

# %%
Score = 25

# %%
print(Score)
# Out:
# 25
