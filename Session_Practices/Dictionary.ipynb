# %%
Student = {"Name":"Kashif","Age":26,"City":"Hangu"}
print(Student)
# Out:
# {'Name': 'Kashif', 'Age': 26, 'City': 'Hangu'}

# %%
Student.update({"Age":24})
print(Student)
# Out:
# {'Name': 'Kashif', 'Age': 24, 'City': 'Hangu'}
