# %% [raw]
# Typecasting (or type conversion)
# Typecasting is simply the process of changing a variable from one data type to another.
#
# For Integer int()
# For Float   float()
#
# For String str()
# Boolean    bool()

# %%
marks= 50
#print(type(marks))

# %%
print(type(marks))
# Out:
# <class 'int'>

# %%
# Now Conveting this marks in float because we know that the marks in decimal number 
print(type(float(marks)))
# Out:
# <class 'float'>

# %%
Score = 60.0
print(Score)
print(type(Score))
# Out:
# 60.0
# <class 'float'>

# %%
# Now we Convert this in to integer because we know that the Score is Intger Number (Whole Number)
print(int(Score))
print(type(Score))
# Out:
# 60
# <class 'float'>
