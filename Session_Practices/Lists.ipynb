# %% [markdown]
# ## List

# %% [raw]
# Lists
#            A list in Python is a collection of items (elements) that are ordered,
#            mutable(changeable),and allow duplicate elements.
# Lists are one of the most versatile data structures in Python and are used to store multiple items in a single variable.
# General Syntax
# You can create lists in Python by placing comma-separated elements inside square brackets []. Lists can contain elements of different data types, including other lists.
#
# list_name = [element_1, element_2, element_3, ..., element_n]

# %%
fruit = ["Mango","Apple","Guava","Watermelon"]

# %%
print(fruit)
print(type(fruit))
# Out:
# ['Mango', 'Apple', 'Guava', 'Watermelon']
# <class 'list'>

# %%
student_marks = [100.5,108.5,60.5,60,80,90]
print(student_marks)
print(type(student_marks))
# Out:
# [100.5, 108.5, 60.5, 60, 80, 90]
# <class 'list'>

# %%
salaries = ["56k","70k","90k","85K"]
salaries
# Out:
# ['56k', '70k', '90k', '85K']

# %% [markdown]
# salaries = ["56k","70k","90k","85K",student_marks]
# salaries

# %% [markdown]
# ## Indexing( Accessing of the element)

# %% [raw]
# Indexing
#                 In Python, indexing is how you access individual elements within a list. Every item in a list has a specific position, known as its index.
# Indexing are perforemd in two way in the list one is Positive mean (left to right) where start from o indexing and other is negative mean right to left and start indexing form -1
# Notes
#             We can perform indexing where order is applicable

# %%
# Creating a Score lists
Score = [25,2.5,60,70,90,60,30,20]
print (Score)
# Out:
# [25, 2.5, 60, 70, 90, 60, 30, 20]

# %%
# We can access of a single elements like "70"
Score[4]
# Out:
# 90

# %%
Score[-5]
# Out:
# 70

# %%
Score[2]
# Out:
# 60

# %% [markdown]
# ## Slicing

# %% [raw]
# Slicing
#                	  Slicing allows you to access a range of elements in a  data from sequences like lists, strings, tuples, and bytes.
# The Basic Syntax
# Slicing uses square brackets [] and colons : to define how you want to carve up your sequence:
# Sequence[start:stop:step]
# start: The index where the slice begins (inclusive). Defaults to 0.
# stop: The index where the slice ends (exclusive). The item at this index is not included. Defaults to the end of the sequence.
# step: The increment between each item in the slice. Defaults to 1

# %%
student_marks = [40,60,30,40,30,10,70,40,30,10]
print(student_marks)
# Out:
# [40, 60, 30, 40, 30, 10, 70, 40, 30, 10]

# %%
# we are accessing to range of element in positive

# %%
print(student_marks[1:4])
# Out:
# [60, 30, 40]

# %%
# IN case w can give start position not end position

# %%
print(student_marks[2:])
# Out:
# [30, 40, 30, 10, 70, 40, 30, 10]

# %%
#  IN case we can give end postion and to start

# %%
print(student_marks[:7])
# Out:
# [40, 60, 30, 40, 30, 10, 70]

# %%
# in case can give start position in in negative

# %%
print(student_marks[-6:-1])
# Out:
# [30, 10, 70, 40, 30]

# %%
print(student_marks[-8:])
# Out:
# [30, 40, 30, 10, 70, 40, 30, 10]

# %%
print(student_marks[:-1])
# Out:
# [40, 60, 30, 40, 30, 10, 70, 40, 30]

# %% [markdown]
# ## Modifying List

# %% [raw]
# Modifying List
#                       	Lists are mutable, meaning you can change their content after creation. You can add, remove, or change elements in a list
# Method:
#
#    Python provides several built-in methods to modify and operate on lists. Eg:
# append(): Adds a single element to the end of the list.
# extend(): Adds multiple elements (from another iterable) to the end of the list.
# insert(): Inserts an element at a specified position.
# remove(): Removes the first occurrence of a specified element.
# pop(): Removes and returns an element at a specified index. If no index is specified, it removes and returns the last element.
# clear(): Removes all elements from the list, resulting in an empty list.
# index(): Returns the index of the first occurrence of a specified element.
# count(): Returns the number of occurrences of a specified element.
# sort(): Sorts the list in ascending order by default. You can also sort in descending order and specify custom sorting criteria.
# reverse(): Reverses the elements of the list in place.
# copy(): Returns a shallow copy of the list.

# %%
# We creating a list of my Score 
My_Score = [20,30,40,50,70,80,90,90]
print(My_Score)
# Out:
# [20, 30, 40, 50, 70, 80, 90, 90]

# %% [markdown]
# ## append()
# ### Adds a single element to the end of the list.

# %%
My_Score.appen(100)
My_Score
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 My_Score.appen(100)
#       2 My_Score
#
# AttributeError: 'list' object has no attribute 'appen'

# %%
My_Score.append(100)
My_Score
# Out:
# [20, 30, 40, 50, 70, 80, 90, 90, 100]

# %%
My_Score.append(900)
My_Score
# Out:
# [20, 30, 40, 50, 70, 80, 90, 90, 100, 900]

# %% [markdown]
# ## insert():
# ### Inserts an element at a specified position.
# ### list_name.insert(Position_Numbber,adding new element)

# %%
My_Score
# Out:
# [20, 30, 40, 50, 70, 80, 90, 90, 100, 900]

# %%
# IN Case we try to insert an element of "Kashif" in position in the 3
My_Score.insert(3,'Kashif')
My_Score
# Out:
# [20, 30, 40, 'Kashif', 50, 70, 80, 90, 90, 100, 900]

# %%
My_Score
# Out:
# [20, 30, 40, 'Kashif', 50, 70, 80, 90, 90, 100, 900]

# %%
# Now we we are inserting in a element in list through Manuall
My_Score [5] = "Zeeshan"
My_Score
# Out:
# [20, 30, 40, 'Kashif', 50, 'Zeeshan', 80, 90, 90, 100, 900]

# %%
# Now we try ot upadte multiple Values through Silice
My_Score [6:8]
# Out:
# [80, 90]

# %%
# Now we we are inserting elements in list through Mannual 
My_Score [6:8] = "Ali","Zohaib"
My_Score
# Out:
# [20, 30, 40, 'Kashif', 50, 'Zeeshan', 'Ali', 'Zohaib', 90, 100, 900]

# %% [markdown]
# ## remove():
# ### Removes the first occurrence of a specified element.
# ### It take value not index number where you want to remove from the list
# ### List_name.reomve.(Value_of_element)

# %%
My_Score
# Out:
# [20, 30, 40, 'Kashif', 50, 'Zeeshan', 'Ali', 'Zohaib', 90, 100, 900]

# %%
# we are remving an element of the above list susch as "Kashif"
My_Score.remove("Kashif")
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 'Ali', 'Zohaib', 90, 100, 900]

# %%
# IN case we try to remove all through remove method
My_Score.remove()
My_Score
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # IN case we try to remove all through remove method
# ----> 2 My_Score.remove()
#       3 My_Score
#
# TypeError: list.remove() takes exactly one argument (0 given)

# %%
# IN case we try to remove multiple elements 
My_Score.remove(20,30)
My_Score
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # IN case we try to remove multiple elements
# ----> 2 My_Score.remove(20,30)
#       3 My_Score
#
# TypeError: list.remove() takes exactly one argument (2 given)

# %%
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 'Ali', 'Zohaib', 90, 100, 900]

# %%
# in case we try to give index number and we to remove "Ali"
My_Score.remove(5)
My_Score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # in case we try to give index number and we to remove "Ali"
# ----> 2 My_Score.remove(5)
#       3 My_Score
#
# ValueError: list.remove(x): x not in list

# %%
My_Score.remove('Ali')
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 'Zohaib', 90, 100, 900]

# %% [markdown]
# ## pop():
# ### Removes and returns an element at a specified index.
# ### If no index is specified, it removes and returns the last element.

# %%
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 'Zohaib', 90, 100, 900]

# %%
# in Case we try to remove element of "Zohaib" and given index number
My_Score.pop(5)
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 90, 100, 900]

# %%
# in Case we try to reomve "Zeeshan" and given to value not position of the element
My_Score.pop("Zeeshan")
My_Score
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # in Case we try to reomve "Zeeshan" and given to value not position of the element
# ----> 2 My_Score.pop("Zeeshan")
#       3 My_Score
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 90, 100, 900]

# %%
# in Case we try to to use pop() and do not give any position of the element then the pop() will remove the last element of the list
My_Score.pop()
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 90, 100]

# %%
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 90, 100]

# %% [markdown]
# ## count():
# ### Returns the number of occurrences of a specified element.
# ### It take Value of the elements of a list not position

# %%
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 90, 100]

# %%
My_Score.count("Zeeshan")
# Out:
# 1

# %%
My_Daily_test_Marks = [20,40,60,4,40,40,60,90,80,70,70,90,90,80,30,40,30,30]
My_Daily_test_Marks
# Out:
# [20, 40, 60, 4, 40, 40, 60, 90, 80, 70, 70, 90, 90, 80, 30, 40, 30, 30]

# %%
# we try to count no of element repeat of  a list "30"
My_Daily_test_Marks.count(30)
# Out:
# 3

# %% [markdown]
# ## clear():
# ### Removes all elements from the list, resulting in an empty list.

# %%
# Creating a list of fruits
fruits_list =["Mango","apple","Watermelon","Jumn"]
fruits_list
# Out:
# ['Mango', 'apple', 'Watermelon', 'Jumn']

# %%
# we want to clear all elements of lists
fruits_list.clear()
fruits_list
# Out:
# []

# %% [markdown]
# ## copy():
# ### Returns a shallow copy of the list.

# %%
Copy = My_Daily_test_Marks.copy()
Copy
# Out:
# [20, 40, 60, 4, 40, 40, 60, 90, 80, 70, 70, 90, 90, 80, 30, 40, 30, 30]

# %% [markdown]
# ## extend():
# ### Adds multiple elements (from another iterable) to the end of the list.

# %%
My_Score
# Out:
# [20, 30, 40, 50, 'Zeeshan', 90, 100]

# %%
My_Score.extend(Copy)
My_Score
# Out:
# [20,
#  30,
#  40,
#  50,
#  'Zeeshan',
#  90,
#  100,
#  20,
#  40,
#  60,
#  4,
#  40,
#  40,
#  60,
#  90,
#  80,
#  70,
#  70,
#  90,
#  90,
#  80,
#  30,
#  40,
#  30,
#  30]

# %% [markdown]
# ## index():
# ### Returns the index of the first occurrence of a specified element.

# %%
My_Score
# Out:
# [20,
#  30,
#  40,
#  50,
#  'Zeeshan',
#  90,
#  100,
#  20,
#  40,
#  60,
#  4,
#  40,
#  40,
#  60,
#  90,
#  80,
#  70,
#  70,
#  90,
#  90,
#  80,
#  30,
#  40,
#  30,
#  30]

# %%
My_Score.index(20)
# Out:
# 0

# %%
My_Score.index(40)
# Out:
# 2

# %% [markdown]
# ## reverse():
# ### Reverses the elements of the list in place.

# %%
My_Score
# Out:
# [20,
#  30,
#  40,
#  50,
#  'Zeeshan',
#  90,
#  100,
#  20,
#  40,
#  60,
#  4,
#  40,
#  40,
#  60,
#  90,
#  80,
#  70,
#  70,
#  90,
#  90,
#  80,
#  30,
#  40,
#  30,
#  30]

# %%
My_Score.reverse()
My_Score
# Out:
# [30,
#  30,
#  40,
#  30,
#  80,
#  90,
#  90,
#  70,
#  70,
#  80,
#  90,
#  60,
#  40,
#  40,
#  4,
#  60,
#  40,
#  20,
#  100,
#  90,
#  'Zeeshan',
#  50,
#  40,
#  30,
#  20]

# %% [markdown]
# ## sort():
# ### Sorts the list in ascending order by default.
# ### You can also sort in descending order and specify custom sorting criteria.

# %%
My_Score.sort()
My_Score
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 My_Score.sort()
#       2 My_Score
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
Copy
# Out:
# [20, 40, 60, 4, 40, 40, 60, 90, 80, 70, 70, 90, 90, 80, 30, 40, 30, 30]

# %%
Copy.sort()
Copy
# Out:
# [4, 20, 30, 30, 30, 40, 40, 40, 40, 60, 60, 70, 70, 80, 80, 90, 90, 90]

# %%
# for Decending Order
Copy.sort(reverse=True)
Copy
# Out:
# [90, 90, 90, 80, 80, 70, 70, 60, 60, 40, 40, 40, 40, 30, 30, 30, 20, 4]

# %% [markdown]
# ## Practice of Method
# ## Test

# %%
# list
# Create a list: [10, 20, 30]
## Insert 15 at index 1

# %%
Nums = [10,20,30]
Nums
# Out:
# [10, 20, 30]

# %%
# add in 15 in index number 1
Nums.insert(1,15)
Nums
# Out:
# [10, 15, 20, 30]

# %%
# Create a list of colors.
# Remove one color using remove().

#Remove "apple" from this list:
# ["banana", "apple", "mango"]

# %%
Colors_list = ["Read","White","Yellow","Green"]
Colors_list
# Out:
# ['Read', 'White', 'Yellow', 'Green']

# %%
# Removing "Yellow" form the list
Colors_list.remove("Yellow")
Colors_list
# Out:
# ['Read', 'White', 'Green']

# %%
# Remove "apple" from this list:
# ["banana", "apple", "mango"]

# %%
fruits_list = ['banana','Apple','mango']
fruits_list
# Out:
# ['banana', 'Apple', 'mango']

# %%
# Removing 'Apple' from the list 
fruits_list.remove('Apple')
fruits_list
# Out:
# ['banana', 'mango']

# %%
# Sort this list in ascending order:
# [5, 2, 9, 1, 7]

# %%
num_list = [5,2,9,1,7]
num_list
# Out:
# [5, 2, 9, 1, 7]

# %%
num_list.sort(reverse=True)
num_list
# Out:
# [9, 7, 5, 2, 1]

# %%
# Find the index of "mango" in:
# ["apple", "mango", "banana"]

# %%
Fruits_list = ["apple", "mango", "banana"]
Fruits_list
# Out:
# ['apple', 'mango', 'banana']

# %%
# now we find the index number of "mango"
Fruits_list.index('mango')
# Out:
# 1
